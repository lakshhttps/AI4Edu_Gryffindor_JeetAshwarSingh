# %%
import os

# %%
SCRIPT_DIR = os.path.dirname(os.path.abspath('/nlsasfs/home/gpucbh/vyakti11/iitrpr11/tasks'))

DATA_DIR = os.path.join(SCRIPT_DIR, 'data/Train')

DATA_DIR = os.path.normpath(DATA_DIR)

# %%
import os
import sys
import cv2
import numpy as np
import pandas as pd
from scipy.signal import detrend

def POS_WANG(signal, fps):
    """
    Plain-Orthogonal-to-Skin (POS) Algorithm.
   
    Args:
        signal (np.array): Input RGB signal with shape (Frames, 3)
        fps (float): Frames per second
       
    Returns:
        np.array: The extracted rPPG waveform
    """

    C = signal.T  
   
    mean_C = np.mean(C, axis=1, keepdims=True)
    C = C / mean_C - 1

    X = C[1, :] - C[2, :]  
    Y = C[1, :] + C[2, :] - 2 * C[0, :] 

    X_std = np.std(X)
    Y_std = np.std(Y)
   
    if Y_std == 0:
        h = X
    else:
        alpha = X_std / Y_std
        h = X + alpha * Y

    h = detrend(h)
    return h

DATA_DIR = os.path.normpath(DATA_DIR)

META_FILE = os.path.join(DATA_DIR, "labels_train.xlsx")

print(f" Script Location: {SCRIPT_DIR}")
print(f" Data Location:   {DATA_DIR}")

if not os.path.exists(DATA_DIR):
    print(f" Error: The directory '{DATA_DIR}' does not exist.")
    print("Please ensure your folder structure is:")
    print("  /ParentFolder")
    print("     |-- /task (contains this script)")
    print("     |-- /data (contains videos)")
    sys.exit() # Stop execution if data is missing

# ---- 3. FACE DETECTION ----
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

def extract_face(frame):
    """Detects the largest face in the frame."""
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    if len(faces) == 0:
        return None

    x, y, w, h = max(faces, key=lambda b: b[2] * b[3])
    return frame[y:y+h, x:x+w]

def extract_rgb_signal(video_path):
    """Extracts the mean RGB signal from the face ROI."""
    cap = cv2.VideoCapture(video_path)
    rgb_signals = []

    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return np.array([])

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        face = extract_face(frame)
       
        if face is None:
            continue

        try:
            face = cv2.resize(face, (128, 128))
            face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
            mean_rgb = np.mean(face.reshape(-1, 3), axis=0)
            rgb_signals.append(mean_rgb)
        except Exception:
            continue

    cap.release()
    return np.array(rgb_signals)

def main():
    if not os.path.exists(META_FILE):
        print("Notice: Metadata file not found. Scanning 'data' folder for videos...")
        video_files = [f for f in os.listdir(DATA_DIR) if f.endswith(('.mp4', '.avi', '.mov'))]
       
        if not video_files:
            print(f"Error: No videos found in {DATA_DIR}.")
            return
           
        df = pd.DataFrame({'video': video_files, 'label': [0] * len(video_files)})
    else:
        df = pd.read_excel(META_FILE)

    results = {}

    for _, row in df.iterrows():
        video_name = row["video"]
        label = row["label"]
        video_path = os.path.join(DATA_DIR, video_name)

        print(f"Processing: {video_name}...")

        if not os.path.exists(video_path):
            print(f"Warning: File not found ({video_name}). Skipping.")
            continue

        cap = cv2.VideoCapture(video_path)
        fps = cap.get(cv2.CAP_PROP_FPS)
        cap.release()

        rgb_signal = extract_rgb_signal(video_path)

        if len(rgb_signal) < fps:
            print(f"Skipping {video_name}: Signal too short or face not detected.")
            continue

        try:
            rppg_waveform = POS_WANG(rgb_signal, fps)
           
            results[video_name] = {
                "label": label,
                "rppg": rppg_waveform
            }
            print(f"Success: {video_name} | Waveform Length: {len(rppg_waveform)}")

        except Exception as e:
            print(f"Error processing {video_name}: {e}")

    output_path = os.path.join(DATA_DIR, "rppg_waveforms_pos.npy")
    if results:
        np.save(output_path, results)
        print(f"\nAll rPPG signals have been saved to: {output_path}")
    else:
        print("\nNo data was saved.")

if __name__ == "__main__":
    main()
# Out:
# 📂 Script Location: /nlsasfs/home/gpucbh/vyakti11/iitrpr11
# 📂 Data Location:   /nlsasfs/home/gpucbh/vyakti11/iitrpr11/data/Train
# Processing: subject_10_Vid_6.avi...
# Warning: File not found (subject_10_Vid_6.avi). Skipping.
# Processing: subject_11_Vid_6.MP4...
# Warning: File not found (subject_11_Vid_6.MP4). Skipping.
# Processing: subject_12_Vid_6.MP4...
# Warning: File not found (subject_12_Vid_6.MP4). Skipping.
# Processing: subject_15_Vid_6.avi...
# Warning: File not found (subject_15_Vid_6.avi). Skipping.
# Processing: subject_16_Vid_6.MP4...
# Warning: File not found (subject_16_Vid_6.MP4). Skipping.
# Processing: subject_18_Vid_6.webm...
# Warning: File not found (subject_18_Vid_6.webm). Skipping.
# Processing: subject_1_Vid_5.avi...
# Warning: File not found (subject_1_Vid_5.avi). Skipping.
# Processing: subject_20_Vid_2.avi...
# Success: subject_20_Vid_2.avi | Waveform Length: 2719
# Processing: subject_20_Vid_5_2.avi...
# Warning: File not found (subject_20_Vid_5_2.avi). Skipping.
# Processing: subject_20_Vid_6.avi...
# Success: subject_20_Vid_6.avi | Waveform Length: 2407
# Processing: subject_20_Vid_7.avi...
# Warning: File not found (subject_20_Vid_7.avi). Skipping.
# Processing: subject_21_Vid_5.avi...
# Warning: File not found (subject_21_Vid_5.avi). Skipping.
# Processing: subject_23_Vid_5.avi...
# Success: subject_23_Vid_5.avi | Waveform Length: 5081
# Processing: subject_3_Vid_2.avi...
# Warning: File not found (subject_3_Vid_2.avi). Skipping.
# Processing: subject_3_Vid_5.avi...
# Warning: File not found (subject_3_Vid_5.avi). Skipping.
# Processing: subject_3_Vid_7.avi...
# Warning: File not found (subject_3_Vid_7.avi). Skipping.
# Processing: subject_4_Vid_6.MP4...
# Warning: File not found (subject_4_Vid_6.MP4). Skipping.
# Processing: subject_6_Vid_6.MP4...
# Warning: File not found (subject_6_Vid_6.MP4). Skipping.
# Processing: subject_7_Vid_2.avi...
# Warning: File not found (subject_7_Vid_2.avi). Skipping.
# Processing: subject_7_Vid_4.avi...
# Warning: File not found (subject_7_Vid_4.avi). Skipping.
# Processing: subject_9_Vid_6.webm...
# Warning: File not found (subject_9_Vid_6.webm). Skipping.
# Processing: subject_26_Vid_2.avi...
# Warning: File not found (subject_26_Vid_2.avi). Skipping.
# Processing: subject_26_Vid_4.avi...
# Warning: File not found (subject_26_Vid_4.avi). Skipping.
# Processing: subject_26_Vid_5.avi...
# Warning: File not found (subject_26_Vid_5.avi). Skipping.
# Processing: subject_26_Vid_7.avi...
# Warning: File not found (subject_26_Vid_7.avi). Skipping.
# Processing: subject_29_Vid_7.wmv...
# Success: subject_29_Vid_7.wmv | Waveform Length: 4116
# Processing: subject_32_Vid_6.avi...
# Success: subject_32_Vid_6.avi | Waveform Length: 2473
# Processing: subject_32_Vid_7.webm...
# Warning: File not found (subject_32_Vid_7.webm). Skipping.
# Processing: subject_33_Vid_1.avi...
# Success: subject_33_Vid_1.avi | Waveform Length: 1985
# Processing: subject_33_Vid_2.avi...
# Warning: File not found (subject_33_Vid_2.avi). Skipping.
# Processing: subject_34_Vid_3.webm...
# Success: subject_34_Vid_3.webm | Waveform Length: 7770
# Processing: subject_34_Vid_7.webm...
# Success: subject_34_Vid_7.webm | Waveform Length: 10331
# Processing: subject_35_Vid_7.wmv...
# Success: subject_35_Vid_7.wmv | Waveform Length: 4692
# Processing: subject_37_Vid_7.avi...
# Success: subject_37_Vid_7.avi | Waveform Length: 8648
# Processing: subject_40_Vid_7.wmv...
# Success: subject_40_Vid_7.wmv | Waveform Length: 3690
# Processing: subject_41_Vid_2.avi...
# Success: subject_41_Vid_2.avi | Waveform Length: 732
# Processing: subject_41_Vid_7.avi...
# Warning: File not found (subject_41_Vid_7.avi). Skipping.
# Processing: subject_42_Vid_7.webm...
# Success: subject_42_Vid_7.webm | Waveform Length: 10463
# Processing: subject_44_Vid_7.MP4...
# Warning: File not found (subject_44_Vid_7.MP4). Skipping.
# Processing: subject_47_Vid_6.wmv...
# Success: subject_47_Vid_6.wmv | Waveform Length: 3676
# Processing: subject_48_Vid_6.wmv...
# Success: subject_48_Vid_6.wmv | Waveform Length: 3701
# Processing: subject_48_Vid_7.wmv...
# Success: subject_48_Vid_7.wmv | Waveform Length: 4735
# Processing: subject_50_Vid_4.avi...
# Warning: File not found (subject_50_Vid_4.avi). Skipping.
# Processing: subject_51_Vid_7.avi...
# Warning: File not found (subject_51_Vid_7.avi). Skipping.
# Processing: subject_52_Vid_7.webm...
# [matroska,webm @ 0x5639c193fc40] File ended prematurely at pos. 12082631 (0xb85dc7)
# [opus @ 0x5639c18f1500] Error parsing Opus packet header.
# Success: subject_52_Vid_7.webm | Waveform Length: 9172
# Processing: subject_53_Vid_3.avi...
# Success: subject_53_Vid_3.avi | Waveform Length: 820
# Processing: subject_56_Vid_3.avi...
# Success: subject_56_Vid_3.avi | Waveform Length: 513
# Processing: subject_62_Vid_3.avi...
# Success: subject_62_Vid_3.avi | Waveform Length: 3094
# Processing: subject_62_Vid_4.avi...
# Success: subject_62_Vid_4.avi | Waveform Length: 3270
# Processing: subject_62_Vid_5.avi...
# Success: subject_62_Vid_5.avi | Waveform Length: 2875
# Processing: subject_62_Vid_7.avi...
# Warning: File not found (subject_62_Vid_7.avi). Skipping.
# Processing: subject_64_Vid_7.wmv...
# Success: subject_64_Vid_7.wmv | Waveform Length: 4846
# Processing: subject_65_Vid_6.avi...
# Warning: File not found (subject_65_Vid_6.avi). Skipping.
# Processing: subject_66_Vid_7.wmv...
# Success: subject_66_Vid_7.wmv | Waveform Length: 567
# Processing: subject_67_Vid_1.avi...
# Success: subject_67_Vid_1.avi | Waveform Length: 3655
# Processing: subject_69_Vid_6.wmv...
# Success: subject_69_Vid_6.wmv | Waveform Length: 3679
# Processing: subject_70_Vid_1.avi...
# Warning: File not found (subject_70_Vid_1.avi). Skipping.
# Processing: subject_70_Vid_2.avi...
# Warning: File not found (subject_70_Vid_2.avi). Skipping.
# Processing: subject_70_Vid_5.avi...
# Warning: File not found (subject_70_Vid_5.avi). Skipping.
# Processing: subject_72_Vid_6.wmv...
# Success: subject_72_Vid_6.wmv | Waveform Length: 3686
# Processing: subject_73_Vid_7.wmv...
# Success: subject_73_Vid_7.wmv | Waveform Length: 1991
# Processing: subject_77_Vid_7.avi...
# Warning: File not found (subject_77_Vid_7.avi). Skipping.
# Processing: subject_79_Vid_7.wmv...
# Skipping subject_79_Vid_7.wmv: Signal too short or face not detected.
# Processing: subject_80_Vid_1.avi...
# Success: subject_80_Vid_1.avi | Waveform Length: 3461
# Processing: subject_80_Vid_4.avi...
# Success: subject_80_Vid_4.avi | Waveform Length: 2750
# Processing: subject_81_Vid_7.webm...
# Warning: File not found (subject_81_Vid_7.webm). Skipping.
# Processing: subject_82_Vid_7.avi...
# Success: subject_82_Vid_7.avi | Waveform Length: 4764
# Processing: subject_83_Vid_7.webm...
# Warning: File not found (subject_83_Vid_7.webm). Skipping.
# Processing: subject_84_Vid_1.avi...
# Success: subject_84_Vid_1.avi | Waveform Length: 3598
# Processing: subject_84_Vid_2.avi...
# Success: subject_84_Vid_2.avi | Waveform Length: 2870
# Processing: subject_84_Vid_3.avi...
# Success: subject_84_Vid_3.avi | Waveform Length: 2623
# Processing: subject_84_Vid_4.avi...
# Success: subject_84_Vid_4.avi | Waveform Length: 3032
# Processing: subject_85_Vid_7.avi...
# Warning: File not found (subject_85_Vid_7.avi). Skipping.
# Processing: subject_86_Vid_7.avi...
# Success: subject_86_Vid_7.avi | Waveform Length: 3575
#
# All rPPG signals have been saved to: /nlsasfs/home/gpucbh/vyakti11/iitrpr11/data/Train/rppg_waveforms_pos.npy
